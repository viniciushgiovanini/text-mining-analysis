# %% [markdown]
# ## AS01: Pré-Processamento Textual
#
# **Aluno: Vinícius Henrique Giovanini**
# **Matricula: 692225**
# **Professor: Wladmir Cardoso Brandão**

# %%
## Criação dos diretorios necessários caso não exista
import os

path1 = '../datasets/'
path2 = "../saidas/"

if not os.path.exists(path1):
    os.makedirs(path1)
if not os.path.exists(path2):
    os.makedirs(path2)

# %%
# Realizando Leitura do Arquivo, e mapeando cada linha para um dicionário, conseguindo assim controlar cada alteração por linha.
# Removendo as quebras de linhas e pulando linhas que são vazias

shakespeare_dict = {}

cont = 1

with open("../datasets/Shakespeare.txt", 'r') as arquivo:
  
  
  for linha in arquivo:
    shakespeare_dict[f'Linha {cont}'] = linha.replace("\n", "")
    cont+=1

# %%
shakespeare_dict
# Out:
# {'Linha 1': "That, poor contempt, or claim'd thou slept so faithful,",
#  'Linha 2': 'I may contrive our father; and, in their defeated queen,',
#  'Linha 3': 'Her flesh broke me and puttance of expedition house,',
#  'Linha 4': 'And in that same that ever I lament this stomach,',
#  'Linha 5': 'And he, nor Butly and my fury, knowing everything',
#  'Linha 6': 'Grew daily ever, his great strength and thought',
#  'Linha 7': 'The bright buds of mine own.',
#  'Linha 8': '',
#  'Linha 9': 'BIONDELLO:',
#  'Linha 10': "Marry, that it may not pray their patience.'",
#  'Linha 11': '',
#  'Linha 12': 'KING LEAR:',
#  'Linha 13': 'The instant common maid, as we may less be',
#  'Linha 14': 'a brave gentleman and joiner: he that finds us with wax',
#  'Linha 15': 'And owe so full of presence and our fooder at our',
#  'Linha 16': "staves. It is remorsed the bridal's man his grace",
#  'Linha 17': 'for every business in my tongue, but I was thinking',
# ...

# %%
len(shakespeare_dict)
# Out:
# 3298

# %% [markdown]
# ### 1. Normalização
# Realizar as seguintes ações de normalização no arquivo de entrada e gerar o arquivo de saída Shakespeare_Normalized.txt.
#
# 1. Lower case reduction
# 2. Accent and diacritic removal
# 3. Canonicalizing of acronyms, currency, date and hyphenated words
# 4. Punctuation removal (except currency and date).
# 5. Special characters removal

# %%
# imports
import re
import unicodedata


# (1.1) Iterando o dicionario por key e value, aplicando o toLowerCase em todas as linhas do dicionário já mapeadas

for linha, valor in shakespeare_dict.items():
  
  ## (1.1) Colocando cada linha com lowerCase
  texto_normalizado = valor.lower()
  
  ## (1.2) Removendo acentos e diatrícos
  texto_normalizado = unicodedata.normalize('NFD', texto_normalizado)
  texto_normalizado = re.sub(r'[\u0300-\u036f]', '', texto_normalizado)
  
  ## (1.3) Canonização de siglas, moeda, data e palavras hifenizadas

  # Juntando string com hifem
  texto_canonizado =  texto_normalizado.replace("-", "")
  # Tratando data para manter DD/MM/YYYY
  texto_canonizado = re.sub(r'(\d{2})/(\d{2})/(\d{4})', r'\3-\2-\1', texto_canonizado)
  
  ## (1.4) Removendo pontuação exceto caso sej data.
  
  # Remove todas as pontuações
  texto_sem_pontuacao = re.sub(r'[^\w\s]|_', '', texto_canonizado)
  
  # Faz uma restauração caso encontre o padrão data seja encontado (DD/MM/YYYY)
  texto_sem_pontuacao = re.sub(r'\b\d{2}/\d{2}/\d{4}\b', lambda match: match.group(), texto_sem_pontuacao)
  
  
  ## (1.5) Removendo caracteres especiais  
  texto_sem_caracteres_especias = re.sub(r'[^\w\s]', '', texto_sem_pontuacao)
  
  # Salvando valor na linha novamente do dicionario
  shakespeare_dict[linha] = texto_sem_caracteres_especias

# %%
shakespeare_dict
# Out:
# {'Linha 1': 'that poor contempt or claimd thou slept so faithful',
#  'Linha 2': 'i may contrive our father and in their defeated queen',
#  'Linha 3': 'her flesh broke me and puttance of expedition house',
#  'Linha 4': 'and in that same that ever i lament this stomach',
#  'Linha 5': 'and he nor butly and my fury knowing everything',
#  'Linha 6': 'grew daily ever his great strength and thought',
#  'Linha 7': 'the bright buds of mine own',
#  'Linha 8': '',
#  'Linha 9': 'biondello',
#  'Linha 10': 'marry that it may not pray their patience',
#  'Linha 11': '',
#  'Linha 12': 'king lear',
#  'Linha 13': 'the instant common maid as we may less be',
#  'Linha 14': 'a brave gentleman and joiner he that finds us with wax',
#  'Linha 15': 'and owe so full of presence and our fooder at our',
#  'Linha 16': 'staves it is remorsed the bridals man his grace',
#  'Linha 17': 'for every business in my tongue but i was thinking',
#  'Linha 18': 'that he contends he hath respected thee',
# ...

# %%
with open("../saidas/AS01/Shakespeare_Normalized.txt", 'w') as arquivo:
  for value in shakespeare_dict.values():
    arquivo.write(str(value) + '\n')

# %% [markdown]
# ### 2. Tokenização
# Realizar cada uma das seguintes tokenizações no arquivo ShakespeareNormalized.txt e gerar o arquivo de saída Shakespeare_Normalized_TokenizedXX.txt, onde XX é o número da subtarefa. Por exemplo, o arquivo Shakespeare_Normalized_Tokenized01.txt é a saída do algoritmo 1 (White Space Tokenization):
#
# 1. White Space Tokenization
# 2. NLTK: Word Tokenizer
# 3. NLTK: Tree Bank Tokenizer
# 4. NLTK: Word Punctuation Tokenizer
# 5. NLTK: Tweet Tokenizer
# 6. NLTK: MWE Tokenizer
# 7. TextBlob Word Tokenizer
# 8. spaCy Tokenizer
# 9. Gensim Word Tokenizer
# 10. Keras Tokenization
# Para facilitar, teste primeiramente o funcionamento do código usando o seguinte texto:
#
# ```
# It's true, Ms. Martha Töpfer! $3.00 on 3/21/2023 in cash for an ice-cream in the U.S. market? :-( #Truth
# ```

# %%
text_teste = "It's true, Ms. Martha Töpfer! $3.00 on 3/21/2023 in cash for an ice-cream in the U.S. market? :-( #Truth"

# %%
### Realizando leitura e armazenando em dicionario o novo arquivo já normalizado

shakespeare_dict_normalize = {}

cont = 1

with open("../saidas/AS01/Shakespeare_Normalized.txt", 'r') as arquivo:
  
  
  for linha in arquivo:
    shakespeare_dict_normalize[f'Linha {cont}'] = linha.replace("\n", "")
    cont+=1

# %%
shakespeare_dict_normalize
# Out:
# {'Linha 1': 'that poor contempt or claimd thou slept so faithful',
#  'Linha 2': 'i may contrive our father and in their defeated queen',
#  'Linha 3': 'her flesh broke me and puttance of expedition house',
#  'Linha 4': 'and in that same that ever i lament this stomach',
#  'Linha 5': 'and he nor butly and my fury knowing everything',
#  'Linha 6': 'grew daily ever his great strength and thought',
#  'Linha 7': 'the bright buds of mine own',
#  'Linha 8': '',
#  'Linha 9': 'biondello',
#  'Linha 10': 'marry that it may not pray their patience',
#  'Linha 11': '',
#  'Linha 12': 'king lear',
#  'Linha 13': 'the instant common maid as we may less be',
#  'Linha 14': 'a brave gentleman and joiner he that finds us with wax',
#  'Linha 15': 'and owe so full of presence and our fooder at our',
#  'Linha 16': 'staves it is remorsed the bridals man his grace',
#  'Linha 17': 'for every business in my tongue but i was thinking',
#  'Linha 18': 'that he contends he hath respected thee',
# ...

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Viny\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Viny\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize, WordPunctTokenizer, TweetTokenizer, MWETokenizer
from nltk.tokenize.treebank import TreebankWordTokenizer
from textblob import TextBlob
import spacy
from gensim.corpora import Dictionary

# %%
dict_white_space_tokenization = {}
dict_word_tokenizer = {}
dict_tree_bank_tokenizer = {}
dict_word_punct_tokenizer = {}
dict_tweet_tokenizer = {}
dict_mwe_tokenizer = {}
dict_textblob_tokenizer = {}
dict_gensim_tokenizer = {}

for linha, valor in shakespeare_dict_normalize.items():
  
  # 1. White Space Tokenization
  dict_white_space_tokenization[linha] = valor.split()
  
  # 2. NLTK: Word Tokenizer
  dict_word_tokenizer[linha] = word_tokenize(valor)
  
  # 3. NLTK: Treebank Tokenizer
  tokenizer = TreebankWordTokenizer()
  dict_tree_bank_tokenizer[linha] = tokenizer.tokenize(valor)
  
  # 4. NLTK: Word Punctuation Tokenizer  
  tokenizer_punct = WordPunctTokenizer()
  dict_word_punct_tokenizer[linha] = tokenizer_punct.tokenize(valor)
  
  # 5. NLTK: Twwet Tokenizer
  tknzr = TweetTokenizer()
  dict_tweet_tokenizer[linha] = tknzr.tokenize(valor)
  
  # 6. NLTK: MWE Tokenizer
  tknzr_mwe = MWETokenizer([('poor', 'contempt'), ('good', 'chamber')])
  dict_mwe_tokenizer[linha] = tknzr_mwe.tokenize(valor.split())
  
  # 7. TextBlob
  blob = TextBlob(valor)
  dict_textblob_tokenizer[linha] = blob.words
  
  # 9. Gensim Word Tokenizer
  dict_gensim_tokenizer[linha] = Dictionary([word_tokenize(valor.lower())])
  
    
  

###############################
#          SALVAMENTO         #
###############################
  
# Salvando em arquivo 1 White Space Tokenization
with open("../saidas/AS01/shakespeare_Normalized_Tokenized01.txt", 'w') as arquivo:
  for value in dict_white_space_tokenization.values():
    arquivo.write(str(value) + '\n')
    
# Salvando em arquivo 2 NLTK: Word Tokenizen
with open("../saidas/AS01/shakespeare_Normalized_Tokenized02.txt", 'w') as arquivo:
  for value in dict_word_tokenizer.values():
    arquivo.write(str(value) + '\n')

# Salvando em arquivo 3 NLTK: TreeBank Tokenizer
with open("../saidas/AS01/shakespeare_Normalized_Tokenized03.txt", 'w') as arquivo:
  for value in dict_tree_bank_tokenizer.values():
    arquivo.write(str(value) + '\n')

# Salvando em arquivo 4 NLTK: Word Punctuation Tokenizer
with open("../saidas/AS01/shakespeare_Normalized_Tokenized04.txt", 'w') as arquivo:
  for value in dict_word_punct_tokenizer.values():
    arquivo.write(str(value) + '\n')
    
# Salvando em arquivo 5 NLTK: Tweet Tokenizer
with open("../saidas/AS01/shakespeare_Normalized_Tokenized05.txt", 'w') as arquivo:
  for value in dict_tweet_tokenizer.values():
    arquivo.write(str(value) + '\n')

# Salvando em arquivo 6 NLTK: MWE Tokenizer
with open("../saidas/AS01/shakespeare_Normalized_Tokenized06.txt", 'w') as arquivo:
  for value in dict_mwe_tokenizer.values():
    arquivo.write(str(value) + '\n')

# Salvando em arquivo 7 TextBlob
with open("../saidas/AS01/shakespeare_Normalized_Tokenized07.txt", 'w') as arquivo:
  for value in dict_textblob_tokenizer.values():
    arquivo.write(str(value) + '\n')

# Salvando em arquivo 9 Gensim Dict
with open("../saidas/AS01/shakespeare_Normalized_Tokenized09.txt", 'w') as arquivo:
  for value in dict_gensim_tokenizer.values():
    arquivo.write(str(value) + '\n')

# %% [markdown]
# Obs: Professor, quando fui testar a tokenização pelo spacy ele estava demorando muito, testei diversas maneiras para otimizar, testei lendo sem ser do dicionário, tokezinando o texto inteiro de uma vez, ficou menos legivel no arquivo txt, mas ia demorar muito tokenizar o texto inteiro linha a linha, estava fazendo assim para ficar melhor na exibição do txt mas com essa bib ficou inviavel fazer assim, então fiz a leitura do texto armazenei e passei de uma vez no método, rodando o txt de uma vez rodou em 5.3s

# %%
with open('../saidas/AS01/Shakespeare_Normalized.txt', 'r') as arquivo:
    # Lê todo o conteúdo do arquivo
    text = arquivo.read()


      # 8. spaCy Tokenizer
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(text)

    # Obtém os tokens resultantes
    tk = [token.text for token in doc]
  
  
# Salvando em arquivo 8 spacy
with open("../saidas/AS01/shakespeare_Normalized_Tokenized08.txt", 'w') as arquivo:
 arquivo.write(str(tk))

# %% [markdown]
# Keras Tokenizer: Ficou fora do bloco (celula) dos outros pois o keras tokenizer recebe uma lista como parametro contendo todas as sentenças necessárias, nos outros estava passando cada sentença separadamente, ja que este tem essa opção iniciou o texto em uma lista.
#
# Saida: Foi impresso os indices de incidencia de cada palavra

# %%
### Iniciando uma lista com todas as linhas do txt para serem tokenizadas com keras
shakespeare_list_keras_tokenizer = []

with open("../saidas/AS01/Shakespeare_Normalized.txt", 'r') as arquivo:
  for linha in arquivo:
    shakespeare_list_keras_tokenizer.append(linha.replace("\n", ""))

# %%
import tensorflow as tf

tokenizer = tf.keras.preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(shakespeare_list_keras_tokenizer)
indices = tokenizer.word_index
sentencas = tokenizer.texts_to_sequences(shakespeare_list_keras_tokenizer)

with open("../saidas/AS01/shakespeare_Normalized_Tokenized10.txt", 'w') as arquivo:
  for key, value in indices.items():
    arquivo.write(str(key) + ":" + str(value) + '\n')

# %% [markdown]
# ### 3. Stop-words Removal
# Realizar a remoção de stop-words do texto (apenas o da subtarefa 2 de tokenização), e gerar um arquivo de saída denominado Shakespeare_Normalized_Tokenized_StopWord.txt.

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Viny\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
sw = stopwords.words('english')

print(sw)


dict_sem_stopwords = {}

for linha, valor in shakespeare_dict_normalize.items():
 
  no_stop_word_line = [ word for word in word_tokenize(valor) if not word in sw]
  
  dict_sem_stopwords[linha] = no_stop_word_line.copy()
  
  
with open("../saidas/AS01/shakespeare_Normalized_Tokenized_StopWord.txt", 'w') as arquivo:
  for key, value in dict_sem_stopwords.items():
    arquivo.write(str(value) + '\n')
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
dict_sem_stopwords
# Out:
# {'Linha 1': ['poor', 'contempt', 'claimd', 'thou', 'slept', 'faithful'],
#  'Linha 2': ['may', 'contrive', 'father', 'defeated', 'queen'],
#  'Linha 3': ['flesh', 'broke', 'puttance', 'expedition', 'house'],
#  'Linha 4': ['ever', 'lament', 'stomach'],
#  'Linha 5': ['butly', 'fury', 'knowing', 'everything'],
#  'Linha 6': ['grew', 'daily', 'ever', 'great', 'strength', 'thought'],
#  'Linha 7': ['bright', 'buds', 'mine'],
#  'Linha 8': [],
#  'Linha 9': ['biondello'],
#  'Linha 10': ['marry', 'may', 'pray', 'patience'],
#  'Linha 11': [],
#  'Linha 12': ['king', 'lear'],
#  'Linha 13': ['instant', 'common', 'maid', 'may', 'less'],
#  'Linha 14': ['brave', 'gentleman', 'joiner', 'finds', 'us', 'wax'],
#  'Linha 15': ['owe', 'full', 'presence', 'fooder'],
#  'Linha 16': ['staves', 'remorsed', 'bridals', 'man', 'grace'],
#  'Linha 17': ['every', 'business', 'tongue', 'thinking'],
#  'Linha 18': ['contends', 'hath', 'respected', 'thee'],
#  'Linha 19': [],
#  'Linha 20': ['biron'],
# ...

# %% [markdown]
# ### 4. Text Lemmatization
# Realizar a lematização do texto gerado na etapa anterior, utilizando o WordNet Lemmatizer e gerar um arquivo de saída denominado Shakespeare_Normalized_Tokenized_StopWord_Lemmatized.txt.

# %%
from nltk.stem import WordNetLemmatizer

# Dicionario do lemmatizer
dict_lemmatizer = {}

lemmatizer = WordNetLemmatizer()
# Iterando no dicionario contendo os stopwords
for linha, valor in dict_sem_stopwords.items():
  dict_lemmatizer[linha] = [lemmatizer.lemmatize(word) for word in valor]


with open("../saidas/AS01/Shakespeare_Normalized_Tokenized_StopWord_Lemmatized.txt", 'w') as arquivo:
  for key, value in dict_lemmatizer.items():
    arquivo.write(str(value) + '\n')

# %%
dict_lemmatizer
# Out:
# {'Linha 1': ['poor', 'contempt', 'claimd', 'thou', 'slept', 'faithful'],
#  'Linha 2': ['may', 'contrive', 'father', 'defeated', 'queen'],
#  'Linha 3': ['flesh', 'broke', 'puttance', 'expedition', 'house'],
#  'Linha 4': ['ever', 'lament', 'stomach'],
#  'Linha 5': ['butly', 'fury', 'knowing', 'everything'],
#  'Linha 6': ['grew', 'daily', 'ever', 'great', 'strength', 'thought'],
#  'Linha 7': ['bright', 'bud', 'mine'],
#  'Linha 8': [],
#  'Linha 9': ['biondello'],
#  'Linha 10': ['marry', 'may', 'pray', 'patience'],
#  'Linha 11': [],
#  'Linha 12': ['king', 'lear'],
#  'Linha 13': ['instant', 'common', 'maid', 'may', 'le'],
#  'Linha 14': ['brave', 'gentleman', 'joiner', 'find', 'u', 'wax'],
#  'Linha 15': ['owe', 'full', 'presence', 'fooder'],
#  'Linha 16': ['stave', 'remorsed', 'bridal', 'man', 'grace'],
#  'Linha 17': ['every', 'business', 'tongue', 'thinking'],
#  'Linha 18': ['contends', 'hath', 'respected', 'thee'],
#  'Linha 19': [],
#  'Linha 20': ['biron'],
# ...

# %% [markdown]
# ### 5. Text Stemming
# Aplicar cada um dos seguintes stemmers no arquivo de entrada Shakespeare_Normalized_Tokenized_StopWord_Lemmatized.txt e gerar o arquivo de saída Shakespeare_Normalized_Tokenized_StopWord_Lemmatized_StemmingXX.txt, onde XX é o número da subtarefa. Por exemplo, o arquivo Shakespeare_Normalized_Tokenized_StopWord_Lemmatized_Stemming01.txt é a saída do algoritmo 1 (Porter Stemmer):
#
# 1. Porter Stemmer
# 2. Snowball Stemmer

# %% [markdown]
# ---

# %% [markdown]
# 1. Porter Stemmer

# %%
from nltk.stem.porter import PorterStemmer

stemmer = PorterStemmer()

# Dicionario com Porter Stemmer
dict_porter_stemmer = {}

# O dict_lemmatizer é o dicionario contendo as alterações presente no arquivo Shakespeare_Normalized_Tokenized_StopWord_Lemmatized.txt
for linha, valor in dict_lemmatizer.items():

  dict_porter_stemmer[linha] = [stemmer.stem(word) for word in valor]
  
  
with open("../saidas/AS01/Shakespeare_Normalized_Tokenized_StopWord_Lemmatized_Stemming01.txt", 'w') as arquivo:
  for key, value in dict_porter_stemmer.items():
   arquivo.write(str(value) + '\n')

# %% [markdown]
# ---

# %% [markdown]
# 2. Snowball Stemmer

# %%
from nltk.stem.snowball import SnowballStemmer

stemmer = SnowballStemmer('english')

# Dicionario com Porter Stemmer
dict_snowball_stemmer = {}

#  O dict_lemmatizer é o dicionario contendo as alterações presente no arquivo Shakespeare_Normalized_Tokenized_StopWord_Lemmatized.txt
for linha, valor in dict_lemmatizer.items():

  dict_snowball_stemmer[linha] = [stemmer.stem(word) for word in valor]
  
  
with open("../saidas/AS01/Shakespeare_Normalized_Tokenized_StopWord_Lemmatized_Stemming02.txt", 'w') as arquivo:
  for key, value in dict_snowball_stemmer.items():
   arquivo.write(str(value) + '\n')

# %% [markdown]
# ### 6. Análise do Vocabulário
# Comparar os vocabulários gerados por cada lematizador e stemmer, apresentando um arquivo CSV para cada um deles contendo:
#
# Token (raíz resultante)
# Número de ocorrências do token no documento resultante (lematizado ou com stemming)
# Tamanho em caracteres de cada token do vocabulário
# Por exemplo, para o lematizador, gerar o arquivo Shakespeare_Vocabulary_Lemmatized.csv e para o Porter Stemmer gerar o arquivo Shakespeare_Vocabulary_Porter.csv.
#
# Apresentar um documento final comparativo denominado Shakespeare_Vocabulary_Analysis.txt contendo, para cada lematizador e stemmer utilizado, o tamanho do vocabulário (número de tokens), o número médio de ocorrências e o tamanho médio dos tokens.

# %%
# Leitura do Arquivo Lematizado Stemming com Porter
dict_porter_stemmer = {}
cont = 1
with open('../saidas/AS01/Shakespeare_Normalized_Tokenized_StopWord_Lemmatized_Stemming01.txt', 'r') as file:
  
    for line in file:
      lista = eval(line)
      dict_porter_stemmer["Linha " + str(cont)] = lista.copy()
      cont += 1

cont = 1
dict_snow_stemmer = {}
with open('../saidas/AS01/Shakespeare_Normalized_Tokenized_StopWord_Lemmatized_Stemming02.txt', 'r') as file:
  
    for line in file:
      lista = eval(line)
      dict_snow_stemmer["Linha " + str(cont)] = lista.copy()
      cont += 1

cont = 1
dict_lemmatized_stemmer = {}
with open('../saidas/AS01/Shakespeare_Normalized_Tokenized_StopWord_Lemmatized.txt', 'r') as file:
  
    for line in file:
      lista = eval(line)
      dict_lemmatized_stemmer["Linha " + str(cont)] = lista.copy()
      cont += 1

# %%
dict_porter_stemmer
# Out:
# {'Linha 1': ['poor', 'contempt', 'claimd', 'thou', 'slept', 'faith'],
#  'Linha 2': ['may', 'contriv', 'father', 'defeat', 'queen'],
#  'Linha 3': ['flesh', 'broke', 'puttanc', 'expedit', 'hous'],
#  'Linha 4': ['ever', 'lament', 'stomach'],
#  'Linha 5': ['butli', 'furi', 'know', 'everyth'],
#  'Linha 6': ['grew', 'daili', 'ever', 'great', 'strength', 'thought'],
#  'Linha 7': ['bright', 'bud', 'mine'],
#  'Linha 8': [],
#  'Linha 9': ['biondello'],
#  'Linha 10': ['marri', 'may', 'pray', 'patienc'],
#  'Linha 11': [],
#  'Linha 12': ['king', 'lear'],
#  'Linha 13': ['instant', 'common', 'maid', 'may', 'le'],
#  'Linha 14': ['brave', 'gentleman', 'joiner', 'find', 'u', 'wax'],
#  'Linha 15': ['owe', 'full', 'presenc', 'fooder'],
#  'Linha 16': ['stave', 'remors', 'bridal', 'man', 'grace'],
#  'Linha 17': ['everi', 'busi', 'tongu', 'think'],
#  'Linha 18': ['contend', 'hath', 'respect', 'thee'],
#  'Linha 19': [],
#  'Linha 20': ['biron'],
# ...

# %%
dict_snow_stemmer
# Out:
# {'Linha 1': ['poor', 'contempt', 'claimd', 'thou', 'slept', 'faith'],
#  'Linha 2': ['may', 'contriv', 'father', 'defeat', 'queen'],
#  'Linha 3': ['flesh', 'broke', 'puttanc', 'expedit', 'hous'],
#  'Linha 4': ['ever', 'lament', 'stomach'],
#  'Linha 5': ['but', 'furi', 'know', 'everyth'],
#  'Linha 6': ['grew', 'daili', 'ever', 'great', 'strength', 'thought'],
#  'Linha 7': ['bright', 'bud', 'mine'],
#  'Linha 8': [],
#  'Linha 9': ['biondello'],
#  'Linha 10': ['marri', 'may', 'pray', 'patienc'],
#  'Linha 11': [],
#  'Linha 12': ['king', 'lear'],
#  'Linha 13': ['instant', 'common', 'maid', 'may', 'le'],
#  'Linha 14': ['brave', 'gentleman', 'joiner', 'find', 'u', 'wax'],
#  'Linha 15': ['owe', 'full', 'presenc', 'fooder'],
#  'Linha 16': ['stave', 'remors', 'bridal', 'man', 'grace'],
#  'Linha 17': ['everi', 'busi', 'tongu', 'think'],
#  'Linha 18': ['contend', 'hath', 'respect', 'thee'],
#  'Linha 19': [],
#  'Linha 20': ['biron'],
# ...

# %%
dict_lemmatized_stemmer
# Out:
# {'Linha 1': ['poor', 'contempt', 'claimd', 'thou', 'slept', 'faithful'],
#  'Linha 2': ['may', 'contrive', 'father', 'defeated', 'queen'],
#  'Linha 3': ['flesh', 'broke', 'puttance', 'expedition', 'house'],
#  'Linha 4': ['ever', 'lament', 'stomach'],
#  'Linha 5': ['butly', 'fury', 'knowing', 'everything'],
#  'Linha 6': ['grew', 'daily', 'ever', 'great', 'strength', 'thought'],
#  'Linha 7': ['bright', 'bud', 'mine'],
#  'Linha 8': [],
#  'Linha 9': ['biondello'],
#  'Linha 10': ['marry', 'may', 'pray', 'patience'],
#  'Linha 11': [],
#  'Linha 12': ['king', 'lear'],
#  'Linha 13': ['instant', 'common', 'maid', 'may', 'le'],
#  'Linha 14': ['brave', 'gentleman', 'joiner', 'find', 'u', 'wax'],
#  'Linha 15': ['owe', 'full', 'presence', 'fooder'],
#  'Linha 16': ['stave', 'remorsed', 'bridal', 'man', 'grace'],
#  'Linha 17': ['every', 'business', 'tongue', 'thinking'],
#  'Linha 18': ['contends', 'hath', 'respected', 'thee'],
#  'Linha 19': [],
#  'Linha 20': ['biron'],
# ...

# %% [markdown]
# Realizar o tratamento para criar um dataframe que tera um token por linha e duas colunas contendo o potter e o snow

# %%
import pandas as pd

list_lemmatzed_unique = []
list_porter_unique = []
list_snowball_unique = []

cont = 1


# Concatenando o Lematizer
for key, value in dict_lemmatized_stemmer.items():
  list_lemmatzed_unique += value

# Concatenando o Porter
for key, value in dict_porter_stemmer.items():
  list_porter_unique += value

for key, value in dict_snow_stemmer.items():
  list_snowball_unique += value

# %%
list_lemmatzed_unique, len(list_lemmatzed_unique)
# Out:
# (['poor',
#   'contempt',
#   'claimd',
#   'thou',
#   'slept',
#   'faithful',
#   'may',
#   'contrive',
#   'father',
#   'defeated',
#   'queen',
#   'flesh',
#   'broke',
#   'puttance',
#   'expedition',
#   'house',
#   'ever',
#   'lament',
#   'stomach',
#   'butly',
#   'fury',
#   'knowing',
#   'everything',
#   'grew',
#   'daily',
#   'ever',
#   'great',
#   'strength',
#   'thought',
#   'bright',
#   'bud',
#   'mine',
#   'biondello',
#   'marry',
#   'may',
#   'pray',
#   'patience',
#   'king',
#   'lear',
#   'instant',
#   'common',
#   'maid',
#   'may',
#   'le',
#   'brave',
#   'gentleman',
#   'joiner',
#   'find',
#   'u',
#   'wax',
#   'owe',
#   'full',
#   'presence',
#   'fooder',
#   'stave',
#   'remorsed',
#   'bridal',
#   'man',
#   'grace',
#   'every',
#   'business',
#   'tongue',
#   'thinking',
#   'contends',
#   'hath',
#   'respected',
#   'thee',
#   'biron',
#   'left',
#   'thee',
#   'ill',
#   'die',
#   'blessed',
# ...

# %%
list_porter_unique , len(list_porter_unique)
# Out:
# (['poor',
#   'contempt',
#   'claimd',
#   'thou',
#   'slept',
#   'faith',
#   'may',
#   'contriv',
#   'father',
#   'defeat',
#   'queen',
#   'flesh',
#   'broke',
#   'puttanc',
#   'expedit',
#   'hous',
#   'ever',
#   'lament',
#   'stomach',
#   'butli',
#   'furi',
#   'know',
#   'everyth',
#   'grew',
#   'daili',
#   'ever',
#   'great',
#   'strength',
#   'thought',
#   'bright',
#   'bud',
#   'mine',
#   'biondello',
#   'marri',
#   'may',
#   'pray',
#   'patienc',
#   'king',
#   'lear',
#   'instant',
#   'common',
#   'maid',
#   'may',
#   'le',
#   'brave',
#   'gentleman',
#   'joiner',
#   'find',
#   'u',
#   'wax',
#   'owe',
#   'full',
#   'presenc',
#   'fooder',
#   'stave',
#   'remors',
#   'bridal',
#   'man',
#   'grace',
#   'everi',
#   'busi',
#   'tongu',
#   'think',
#   'contend',
#   'hath',
#   'respect',
#   'thee',
#   'biron',
#   'left',
#   'thee',
#   'ill',
#   'die',
#   'bless',
#   'reason',
#   'natur',
#   'honour',
# ...

# %%
list_snowball_unique, len(list_snowball_unique)
# Out:
# (['poor',
#   'contempt',
#   'claimd',
#   'thou',
#   'slept',
#   'faith',
#   'may',
#   'contriv',
#   'father',
#   'defeat',
#   'queen',
#   'flesh',
#   'broke',
#   'puttanc',
#   'expedit',
#   'hous',
#   'ever',
#   'lament',
#   'stomach',
#   'but',
#   'furi',
#   'know',
#   'everyth',
#   'grew',
#   'daili',
#   'ever',
#   'great',
#   'strength',
#   'thought',
#   'bright',
#   'bud',
#   'mine',
#   'biondello',
#   'marri',
#   'may',
#   'pray',
#   'patienc',
#   'king',
#   'lear',
#   'instant',
#   'common',
#   'maid',
#   'may',
#   'le',
#   'brave',
#   'gentleman',
#   'joiner',
#   'find',
#   'u',
#   'wax',
#   'owe',
#   'full',
#   'presenc',
#   'fooder',
#   'stave',
#   'remors',
#   'bridal',
#   'man',
#   'grace',
#   'everi',
#   'busi',
#   'tongu',
#   'think',
#   'contend',
#   'hath',
#   'respect',
#   'thee',
#   'biron',
#   'left',
#   'thee',
#   'ill',
#   'die',
#   'bless',
#   'reason',
#   'natur',
#   'honour',
# ...

# %% [markdown]
# Vou realizar o tratamento dos tokens, contando quantas vezes aparece cada token e qual o tamanho da string, armazenando esses dados em um dicionario para passar para um dataframe e gerar o csv

# %% [markdown]
# **OBS**: IREI REMOVER A REPETIÇÃO DE TOKENS, para facilitar a analise irei remover essa repetição, assim todos os tokens serão unicos, mas o número de ocorrências retrata quantas vezes ele repetiu, então o token **poor** irá aparecer uma vez no CSV mas terá 21 repetições.

# %% [markdown]
# ---

# %% [markdown]
# Tratando o Lematizador, Potter e Snow e Gerando Csv
#
#
# 1. Token
# 2. Número e Ocorrência do token no documento resultante
# 3. Tamanho em caracteres de cada token do vocabulário

# %%
#################
# Lematizador   #
#################
list_occurrence_number_lemmatized = []
list_word_length_lemmatized = []

#################
#   Porter      #
#################
list_occurrence_number_porter = []
list_word_length_porter = []

#################
#   Snowball    #
#################
list_occurrence_number_snowball = []
list_word_length_snowball = []

# Removendo a repetição de tokens caindo de 9517 tokens para 3102
list_lemmatzed_unique_norepeat = list(set(list_lemmatzed_unique))
list_porter_unique_norepeat = list(set(list_porter_unique))
list_snowball_unique_norepeat = list(set(list_snowball_unique))

for each_word in list_lemmatzed_unique_norepeat:
  list_occurrence_number_lemmatized.append(list_lemmatzed_unique.count(each_word))
  list_word_length_lemmatized.append(len(each_word))

for each_word in list_porter_unique_norepeat:
  list_occurrence_number_porter.append(list_porter_unique.count(each_word))
  list_word_length_porter.append(len(each_word))

for each_word in list_snowball_unique_norepeat:
  list_occurrence_number_snowball.append(list_snowball_unique.count(each_word))
  list_word_length_snowball.append(len(each_word))


  
dict_lemmatized_csv = {
  
  "Token": list_lemmatzed_unique_norepeat,
  "N_Ocorrencia": list_occurrence_number_lemmatized,
  "Length": list_word_length_lemmatized
  
}

dict_porter_csv = {"Token": list_porter_unique_norepeat,
  "N_Ocorrencia": list_occurrence_number_porter,
  "Length": list_word_length_porter}


dict_snowball_csv = {"Token": list_snowball_unique_norepeat,
  "N_Ocorrencia": list_occurrence_number_snowball,
  "Length": list_word_length_snowball
}

df1 = pd.DataFrame(dict_lemmatized_csv)
df1.to_csv("../saidas/AS01/Shakespeare_Vocabulary_Lemmatized.csv")

df2 = pd.DataFrame(dict_porter_csv)
df2.to_csv("../saidas/AS01/Shakespeare_Vocabulary_Porter.csv")

df3 = pd.DataFrame(dict_snowball_csv)
df3.to_csv("../saidas/AS01/Shakespeare_Vocabulary_Snowball.csv")

# %%
print(len(list_lemmatzed_unique_norepeat))
print(len(list_lemmatzed_unique))
# Out:
# 3103
# 9517

# %% [markdown]
# ----

# %% [markdown]
# Gerando arquivo de estatisticas

# %%
# Lemmatizer Stats
tamanho_vocabulario_lematizador = len(list_lemmatzed_unique_norepeat)
media_aparicoes_lematiador = sum(list_occurrence_number_lemmatized) / len(list_occurrence_number_lemmatized)
media_qtd_letras_lematizador = sum(list_word_length_lemmatized) / len(list_word_length_lemmatized)

print("Lemmatizer")
print(tamanho_vocabulario_lematizador)
print(media_aparicoes_lematiador)
print(media_qtd_letras_lematizador)
print("----")

# Porter Stats
tamanho_vocabulario_porter = len(list_porter_unique_norepeat)
media_aparicoes_porter = sum(list_occurrence_number_porter) / len(list_occurrence_number_porter)
media_qtd_letras_porter = sum(list_word_length_porter) / len(list_word_length_porter)

print("Porter")
print(tamanho_vocabulario_porter)
print(media_aparicoes_porter)
print(media_qtd_letras_porter)
print("----")

# Snowball
tamanho_vocabulario_snowball = len(list_snowball_unique_norepeat)
media_aparicoes_snowball = sum(list_occurrence_number_snowball) / len(list_occurrence_number_snowball)
media_qtd_letras_snowball = sum(list_word_length_snowball) / len(list_word_length_snowball)

print("snowball")
print(tamanho_vocabulario_snowball)
print(media_aparicoes_snowball)
print(media_qtd_letras_snowball)
print("----")
# Out:
# Lemmatizer
# 3103
# 3.0670319046084433
# 6.264260393167902
# ----
# Porter
# 2842
# 3.348698099929627
# 5.650246305418719
# ----
# snowball
# 2814
# 3.3820184790334045
# 5.654228855721393
# ----

# %%
stats_lemmatizer = f"Tamanho Lemmatizador: {tamanho_vocabulario_lematizador}\nMedia de aparicoes Lemmatizer: {media_aparicoes_lematiador}\nMedia da qtd de Letras Lemmatizer: {media_qtd_letras_lematizador}\n"
stats_porter = f"Tamanho Porter: {tamanho_vocabulario_porter}\nMedia de aparicoes Porter: {media_aparicoes_porter}\nMedia da qtd de Letras Porter: {media_qtd_letras_porter}\n"
stats_snowball = f"Tamanho Snowball: {tamanho_vocabulario_snowball}\nMedia de aparicoes Snowball: {media_aparicoes_snowball}\nMédia da qtd de Letras Snowball: {media_qtd_letras_snowball}\n"



print(stats_lemmatizer)
print(stats_porter)
print(stats_snowball)
# Out:
# Tamanho Lemmatizador: 3103
# Media de aparicoes Lemmatizer: 3.0670319046084433
# Media da qtd de Letras Lemmatizer: 6.264260393167902
#
# Tamanho Porter: 2842
# Media de aparicoes Porter: 3.348698099929627
# Media da qtd de Letras Porter: 5.650246305418719
#
# Tamanho Snowball: 2814
# Media de aparicoes Snowball: 3.3820184790334045
# Média da qtd de Letras Snowball: 5.654228855721393

# %%
with open('../saidas/AS01/Shakespeare_Vocabulary_Analysis.txt', 'w') as arquivo:
    arquivo.write(stats_lemmatizer + "\n----\n" + stats_porter + "\n----\n"+ stats_snowball)
